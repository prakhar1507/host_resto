# %%
import pandas as pd
import numpy as np

# %%
agra_data=pd.read_csv("agra.csv")
indore_data=pd.read_csv("indore.csv")
lucknow_data=pd.read_csv("lucknow.csv")

# %%
agra_data.head()
# Out:
#                 Restaurent name  \
# 0  Piazza Pizza By Little Italy
# 1        Marleys  The Milkshake
# 2              Molecule Air Bar
# 3   The Salt Cafe Kitchen & Bar
# 4                     Palm Burj
#
#                                        Cuisine types Rating           Price  \
# 0                                              Pizza    3.9    ₹200 for two
# 1  Beverages, Desserts, Ice Cream, Shake, Burger,...    3.7    ₹400 for two
# 2        North Indian, Chinese, Continental, Italian    4.6  ₹2,000 for two
# 3  North Indian, Continental, Chinese, Italian, F...    4.9  ₹1,800 for two
# 4  North Indian, Chinese, Continental, Sushi, Sic...    4.5  ₹2,200 for two
#
#   Distance         Location
# 0   2.5 km    Tajganj, Agra
# 1   3.7 km    Tajganj, Agra
# 2   4.8 km    Tajganj, Agra
# 3   3.8 km    Tajganj, Agra
# 4   1.9 km  Rakabganj, Agra

# %%
agra_data.dtypes
# Out:
# Restaurent name    object
# Cuisine types      object
# Rating             object
# Price              object
# Distance           object
# Location           object
# dtype: object

# %%
lucknow_data.head(20)
# Out:
#               Restaurent name  \
# 0   M E A Cafe And Restaurant
# 1                   Cafè 1991
# 2                  Bigg Daddy
# 3         Remix Veg Food Hall
# 4         Boombox Bar Xchange
# 5               The Big Grill
# 6                     Tanatan
# 7    Rominus Pizza And Burger
# 8            Molecule Air Bar
# 9                 Chinese Wok
# 10                   The Oven
# 11                  Vint Club
# 12                        Que
# 13               Tickled Pink
# 14        The Burger's Castle
# 15                 WOW! China
# 16        Chili's Grill & Bar
# 17                Togo's Momo
# 18      Sky Glass Brewing Co.
# 19           Panorama Terrace
#
#                                         Cuisine types Rating           Price  \
# 0   North Indian, Chinese, BBQ, Fast Food, Beverag...    4.2  ₹1,200 for two
# 1                Coffee, Chinese, Fast Food, Desserts    4.5    ₹700 for two
# 2   North Indian, Mughlai, Continental, Chinese, I...    4.3  ₹2,000 for two
# ...

# %%
(agra_data["Rating"].value_counts()=="New")
# Out:
# Rating
# 3.9    False
# 3.8    False
# -      False
# 4.0    False
# 3.7    False
# 4.1    False
# 3.6    False
# 3.5    False
# 4.2    False
# 4.3    False
# 3.3    False
# New    False
# 3.4    False
# 3.0    False
# 4.4    False
# 3.2    False
# 4.5    False
# 3.1    False
# 4.6    False
# 4.9    False
# 2.7    False
# 2.9    False
# 4.7    False
# 2.6    False
# 2.5    False
# 4.8    False
# Name: count, dtype: bool

# %%
indore_data.head(20)

indore_data["Rating"].value_counts()
# Out:
# Rating
# -      59
# 3.9    57
# 4.2    42
# 3.8    42
# 4.0    40
# 4.1    35
# 4.3    26
# New    26
# 3.7    20
# 4.4    17
# 3.6    16
# 4.5    16
# 3.4    14
# 3.5    14
# 3.3    14
# 3.1    10
# 3.2     9
# 3.0     9
# 4.6     6
# 2.8     6
# 2.9     5
# 4.8     4
# 4.7     4
# 4.9     4
# 2.7     3
# 2.6     2
# 2.5     1
# Name: count, dtype: int64

# %%
lucknow_data.head(20)

lucknow_data["Rating"].value_counts()
# Out:
# Rating
# -      148
# 3.9     51
# New     39
# 4.2     29
# 3.8     25
# 4.0     25
# 4.3     21
# 4.1     21
# 3.7     18
# 4.5     16
# 4.4     16
# 3.5     13
# 3.6     12
# 4.6     12
# 3.3     10
# 3.2      9
# 3.0      9
# 3.4      6
# 4.9      5
# 3.1      5
# 4.7      2
# 2.9      2
# 2.8      2
# 2.5      2
# 2.6      1
# 4.8      1
# 2.4      1
# Name: count, dtype: int64

# %%
# agra_data['Rating'] = agra_data['Rating'].replace('New', 0)
# agra_data['Rating'] = agra_data['Rating'].replace('-', 0)


# agra_data['Rating'] = agra_data['Rating'].astype(float)

# %%
# lucknow_data['Rating'] = lucknow_data['Rating'].replace('New', 0)
# lucknow_data['Rating'] = lucknow_data['Rating'].replace('-', 0)


# lucknow_data['Rating'] = lucknow_data['Rating'].astype(float)

# lucknow_data.head(20)

# %%
# indore_data['Rating'] = indore_data['Rating'].replace('New', 0)
# indore_data['Rating'] = indore_data['Rating'].replace('-', 0)

# indore_data['Rating'] = indore_data['Rating'].astype(float)

# indore_data.head(20)

# %%
lucknow_data.dtypes
lucknow_data["Rating"].value_counts()
# Out:
# Rating
# -      148
# 3.9     51
# New     39
# 4.2     29
# 3.8     25
# 4.0     25
# 4.3     21
# 4.1     21
# 3.7     18
# 4.5     16
# 4.4     16
# 3.5     13
# 3.6     12
# 4.6     12
# 3.3     10
# 3.2      9
# 3.0      9
# 3.4      6
# 4.9      5
# 3.1      5
# 4.7      2
# 2.9      2
# 2.8      2
# 2.5      2
# 2.6      1
# 4.8      1
# 2.4      1
# Name: count, dtype: int64

# %%
indore_data.describe()
# Out:
#        Restaurent name Cuisine types Rating           Price Distance  \
# count              501           501    501             501      501
# unique             490           419     27              38      106
# top       Maa Ki Rasoi  North Indian      -  ₹1,000 for two   2.8 km
# freq                 2            33     59              87       20
#
#                    Location
# count                   501
# unique                   58
# top     Vijay Nagar, Indore
# freq                    142

# %%
# median_value = indore_data["Rating"].median()
# indore_data["Rating"].replace(0,median_value, inplace=True)

# %%
# median_value = lucknow_data["Rating"].median()
# lucknow_data["Rating"].replace(0,median_value, inplace=True)

# %%
# median_value = indore_data["Rating"].median()
# indore_data["Rating"].replace(0,median_value, inplace=True)

# %%
indore_data.describe()
# Out:
#        Restaurent name Cuisine types Rating           Price Distance  \
# count              501           501    501             501      501
# unique             490           419     27              38      106
# top       Maa Ki Rasoi  North Indian      -  ₹1,000 for two   2.8 km
# freq                 2            33     59              87       20
#
#                    Location
# count                   501
# unique                   58
# top     Vijay Nagar, Indore
# freq                    142

# %%
indore_data["Rating"].value_counts().sum()
# Out:
# 501

# %%
agra_data['Rating'].isnull().sum()
# Out:
# 0

# %%
agra_data["Rating"].value_counts().sum()
# Out:
# 501

# %%
agra_data['Rating'].isnull().sum()
# Out:
# 0

# %%
# count_for_two = indore_data['Price'].str.contains('for two').sum()
# count_for_two
# indore_data['Price'] = indore_data['Price'].str.replace(r'[^\d]+', '', regex=True).astype(float)

# %%
# count_for_two = lucknow_data['Price'].str.contains('for two').sum()
# count_for_two
# lucknow_data['Price'] = lucknow_data['Price'].str.replace(r'[^\d]+', '', regex=True).astype(float)

# %%
# lucknow_data['Price']=(lucknow_data['Price']/2)

# %%
# indore_data['Price']=(indore_data['Price']/2)
indore_data.head(52)
indore_data.describe()
# Out:
#        Restaurent name Cuisine types Rating           Price Distance  \
# count              501           501    501             501      501
# unique             490           419     27              38      106
# top       Maa Ki Rasoi  North Indian      -  ₹1,000 for two   2.8 km
# freq                 2            33     59              87       20
#
#                    Location
# count                   501
# unique                   58
# top     Vijay Nagar, Indore
# freq                    142

# %%
indore_data['Distance'] = indore_data['Distance'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
lucknow_data['Distance'] = lucknow_data['Distance'].str.extract(r'(\d+\.?\d*)').astype(float)

condition = lucknow_data["Distance"] > 30


lucknow_data.loc[condition, "Distance"] = lucknow_data["Distance"] / 1000

# %%
condition = indore_data["Distance"] > 30


indore_data.loc[condition, "Distance"] = indore_data[condition]["Distance"] / 1000

# %%
indore_data.describe()
# Out:
#          Distance
# count  501.000000
# mean     5.278190
# std      2.788994
# min      0.973000
# 25%      3.500000
# 50%      4.800000
# 75%      6.200000
# max     25.800000

# %%
indore_data.dtypes
# Out:
# Restaurent name     object
# Cuisine types       object
# Rating              object
# Price               object
# Distance           float64
# Location            object
# dtype: object

# %%
# count_for_two = agra_data['Price'].str.contains('for two').sum()
# count_for_two

# %%
# agra_data['Price'] = agra_data['Price'].str.replace(r'[^\d]+', '', regex=True).astype(float)

# %%
# agra_data['Price']=(agra_data['Price']/2)

# %%
agra_data.head(50)
# Out:
#                               Restaurent name  \
# 0                Piazza Pizza By Little Italy
# 1                      Marleys  The Milkshake
# 2                            Molecule Air Bar
# 3                 The Salt Cafe Kitchen & Bar
# 4                                   Palm Burj
# 5                         Unplugged Courtyard
# 6                                     Hichkee
# 7                             The Numberdaars
# 8                             Barbeque Nation
# 9                                 The Nawaabs
# 10                Oasis - Radisson Hotel Agra
# 11                            Biryani By Kilo
# 12                              Masala Bistro
# 13                       Cafe G - Holiday Inn
# 14                              Downtown Cafe
# 15                             Pinch Of Spice
# 16  Cosmos Cafe & Bar - Fairfield By Marriott
# 17                        My Bar Headquarters
# 18                      Peshawri - ITC Mughal
# ...

# %%
agra_data["Distance"].value_counts()
# Out:
# Distance
# 2.7 km    35
# 2.5 km    27
# 3.8 km    25
# 3.3 km    24
# 4 km      21
#           ..
# 7.3 km     1
# 7.9 km     1
# 7.1 km     1
# 546 m      1
# 1.1 km     1
# Name: count, Length: 80, dtype: int64

# %%
agra_data.describe()
# Out:
#        Restaurent name Cuisine types Rating         Price Distance  \
# count              501           501    501           501      501
# unique             483           372     26            45       80
# top      Bhagat Halwai  North Indian    3.9  ₹300 for two   2.7 km
# freq                 6            49     81            75       35
#
#              Location
# count             501
# unique             32
# top     Tajganj, Agra
# freq              102

# %%
agra_data.head(20)
# Out:
#                               Restaurent name  \
# 0                Piazza Pizza By Little Italy
# 1                      Marleys  The Milkshake
# 2                            Molecule Air Bar
# 3                 The Salt Cafe Kitchen & Bar
# 4                                   Palm Burj
# 5                         Unplugged Courtyard
# 6                                     Hichkee
# 7                             The Numberdaars
# 8                             Barbeque Nation
# 9                                 The Nawaabs
# 10                Oasis - Radisson Hotel Agra
# 11                            Biryani By Kilo
# 12                              Masala Bistro
# 13                       Cafe G - Holiday Inn
# 14                              Downtown Cafe
# 15                             Pinch Of Spice
# 16  Cosmos Cafe & Bar - Fairfield By Marriott
# 17                        My Bar Headquarters
# 18                      Peshawri - ITC Mughal
# ...

# %%
agra_data.dtypes
# Out:
# Restaurent name    object
# Cuisine types      object
# Rating             object
# Price              object
# Distance           object
# Location           object
# dtype: object

# %%
agra_data.isnull().sum()
# Out:
# Restaurent name    0
# Cuisine types      0
# Rating             0
# Price              0
# Distance           0
# Location           0
# dtype: int64

# %%
agra_data['Distance'].value_counts()
# Out:
# Distance
# 2.7 km    35
# 2.5 km    27
# 3.8 km    25
# 3.3 km    24
# 4 km      21
#           ..
# 7.3 km     1
# 7.9 km     1
# 7.1 km     1
# 546 m      1
# 1.1 km     1
# Name: count, Length: 80, dtype: int64

# %%
agra_data['Distance'] = agra_data['Distance'].str.extract(r'(\d+\.?\d*)').astype(float)

# %%
agra_data["Distance"].value_counts()
# Out:
# Distance
# 2.7      35
# 2.5      27
# 3.8      25
# 3.3      24
# 4.0      21
#          ..
# 7.3       1
# 7.9       1
# 7.1       1
# 546.0     1
# 1.1       1
# Name: count, Length: 80, dtype: int64

# %%
agra_data.head(10)
# Out:
#                 Restaurent name  \
# 0  Piazza Pizza By Little Italy
# 1        Marleys  The Milkshake
# 2              Molecule Air Bar
# 3   The Salt Cafe Kitchen & Bar
# 4                     Palm Burj
# 5           Unplugged Courtyard
# 6                       Hichkee
# 7               The Numberdaars
# 8               Barbeque Nation
# 9                   The Nawaabs
#
#                                        Cuisine types Rating           Price  \
# 0                                              Pizza    3.9    ₹200 for two
# 1  Beverages, Desserts, Ice Cream, Shake, Burger,...    3.7    ₹400 for two
# 2        North Indian, Chinese, Continental, Italian    4.6  ₹2,000 for two
# 3  North Indian, Continental, Chinese, Italian, F...    4.9  ₹1,800 for two
# 4  North Indian, Chinese, Continental, Sushi, Sic...    4.5  ₹2,200 for two
# 5  Mediterranean, North Indian, Continental, Chin...    4.4  ₹1,600 for two
# ...

# %%
agra_data.describe()
# Out:
#          Distance
# count  501.000000
# mean    12.284032
# std     74.881588
# min      1.100000
# 25%      2.700000
# 50%      3.800000
# 75%      4.700000
# max    954.000000

# %%
agra_data.head(10)
# Out:
#                 Restaurent name  \
# 0  Piazza Pizza By Little Italy
# 1        Marleys  The Milkshake
# 2              Molecule Air Bar
# 3   The Salt Cafe Kitchen & Bar
# 4                     Palm Burj
# 5           Unplugged Courtyard
# 6                       Hichkee
# 7               The Numberdaars
# 8               Barbeque Nation
# 9                   The Nawaabs
#
#                                        Cuisine types Rating           Price  \
# 0                                              Pizza    3.9    ₹200 for two
# 1  Beverages, Desserts, Ice Cream, Shake, Burger,...    3.7    ₹400 for two
# 2        North Indian, Chinese, Continental, Italian    4.6  ₹2,000 for two
# 3  North Indian, Continental, Chinese, Italian, F...    4.9  ₹1,800 for two
# 4  North Indian, Chinese, Continental, Sushi, Sic...    4.5  ₹2,200 for two
# 5  Mediterranean, North Indian, Continental, Chin...    4.4  ₹1,600 for two
# ...

# %%
condition = agra_data["Distance"] > 30


agra_data.loc[condition, "Distance"] = agra_data[condition]["Distance"] / 1000

# %%
agra_data.head(10)
# Out:
#                 Restaurent name  \
# 0  Piazza Pizza By Little Italy
# 1        Marleys  The Milkshake
# 2              Molecule Air Bar
# 3   The Salt Cafe Kitchen & Bar
# 4                     Palm Burj
# 5           Unplugged Courtyard
# 6                       Hichkee
# 7               The Numberdaars
# 8               Barbeque Nation
# 9                   The Nawaabs
#
#                                        Cuisine types Rating           Price  \
# 0                                              Pizza    3.9    ₹200 for two
# 1  Beverages, Desserts, Ice Cream, Shake, Burger,...    3.7    ₹400 for two
# 2        North Indian, Chinese, Continental, Italian    4.6  ₹2,000 for two
# 3  North Indian, Continental, Chinese, Italian, F...    4.9  ₹1,800 for two
# 4  North Indian, Chinese, Continental, Sushi, Sic...    4.5  ₹2,200 for two
# 5  Mediterranean, North Indian, Continental, Chin...    4.4  ₹1,600 for two
# ...

# %%
agra_data.describe()
# Out:
#          Distance
# count  501.000000
# mean     3.911176
# std      1.690961
# min      0.355000
# 25%      2.700000
# 50%      3.700000
# 75%      4.600000
# max     12.300000

# %%
(agra_data["Rating"]==0).value_counts()
# Out:
# Rating
# False    501
# Name: count, dtype: int64

# %%
agra_data["Rating"].replace(0, 3.374251, inplace=True)

# %%
agra_data.describe()
# Out:
#          Distance
# count  501.000000
# mean     3.911176
# std      1.690961
# min      0.355000
# 25%      2.700000
# 50%      3.700000
# 75%      4.600000
# max     12.300000

# %%
agra_data.head(20)
# Out:
#                               Restaurent name  \
# 0                Piazza Pizza By Little Italy
# 1                      Marleys  The Milkshake
# 2                            Molecule Air Bar
# 3                 The Salt Cafe Kitchen & Bar
# 4                                   Palm Burj
# 5                         Unplugged Courtyard
# 6                                     Hichkee
# 7                             The Numberdaars
# 8                             Barbeque Nation
# 9                                 The Nawaabs
# 10                Oasis - Radisson Hotel Agra
# 11                            Biryani By Kilo
# 12                              Masala Bistro
# 13                       Cafe G - Holiday Inn
# 14                              Downtown Cafe
# 15                             Pinch Of Spice
# 16  Cosmos Cafe & Bar - Fairfield By Marriott
# 17                        My Bar Headquarters
# 18                      Peshawri - ITC Mughal
# ...

# %%
indore_data.head(20)
# Out:
#                                   Restaurent name  \
# 0                     UK Restaurants And Kitchens
# 1                                        Dopamine
# 2                            Epicentre - The Park
# 3                                  House Of Malts
# 4                               The Piano Project
# 5                                 Aqua - The Park
# 6                            Kabelo Veg Barbecues
# 7                           Flame By Fire & Smoke
# 8                                    Cream Centre
# 9                         Cravings - Sayaji Hotel
# 10                                Barbeque Nation
# 11      The Creative Kitchen - Radisson Blu Hotel
# 12                                   Fire & Smoke
# 13                              Revolution Indore
# 14                       The Cube - Hotel Effotel
# 15                  Chopstick City - Sayaji Hotel
# 16                                      Municipal
# 17                                      Mama Loca
# ...

# %%
indore_data.dtypes
# Out:
# Restaurent name     object
# Cuisine types       object
# Rating              object
# Price               object
# Distance           float64
# Location            object
# dtype: object

# %%
agra_data.dtypes
# Out:
# Restaurent name     object
# Cuisine types       object
# Rating              object
# Price               object
# Distance           float64
# Location            object
# dtype: object

# %%
indore_data.dtypes
# Out:
# Restaurent name     object
# Cuisine types       object
# Rating              object
# Price               object
# Distance           float64
# Location            object
# dtype: object

# %%
lucknow_data.dtypes
# Out:
# Restaurent name     object
# Cuisine types       object
# Rating              object
# Price               object
# Distance           float64
# Location            object
# dtype: object

# %%
agra_data.describe()
# Out:
#          Distance
# count  501.000000
# mean     3.911176
# std      1.690961
# min      0.355000
# 25%      2.700000
# 50%      3.700000
# 75%      4.600000
# max     12.300000

# %%
indore_data.describe()
# Out:
#          Distance
# count  501.000000
# mean     5.278190
# std      2.788994
# min      0.973000
# 25%      3.500000
# 50%      4.800000
# 75%      6.200000
# max     25.800000

# %%
lucknow_data.describe()
# Out:
#          Distance
# count  501.000000
# mean     5.905601
# std      3.231083
# min      0.030900
# 25%      3.500000
# 50%      5.600000
# 75%      7.800000
# max     24.900000

# %%
combined_data = pd.concat([agra_data, indore_data, lucknow_data], ignore_index=True)

combined_data.to_csv('new_combined_dataset.csv', index=False)

# %%
df=pd.read_csv("new_combined_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Restaurent name  1503 non-null   object
#  1   Cuisine types    1503 non-null   object
#  2   Rating           1503 non-null   object
#  3   Price            1503 non-null   object
#  4   Distance         1503 non-null   float64
#  5   Location         1503 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 70.6+ KB

# %%
df.head(50)
# Out:
#                               Restaurent name  \
# 0                Piazza Pizza By Little Italy
# 1                      Marleys  The Milkshake
# 2                            Molecule Air Bar
# 3                 The Salt Cafe Kitchen & Bar
# 4                                   Palm Burj
# 5                         Unplugged Courtyard
# 6                                     Hichkee
# 7                             The Numberdaars
# 8                             Barbeque Nation
# 9                                 The Nawaabs
# 10                Oasis - Radisson Hotel Agra
# 11                            Biryani By Kilo
# 12                              Masala Bistro
# 13                       Cafe G - Holiday Inn
# 14                              Downtown Cafe
# 15                             Pinch Of Spice
# 16  Cosmos Cafe & Bar - Fairfield By Marriott
# 17                        My Bar Headquarters
# 18                      Peshawri - ITC Mughal
# ...

# %%
df.columns
# Out:
# Index(['Restaurent name', 'Cuisine types', 'Rating', 'Price', 'Distance',
#        'Location'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Restaurent name  1503 non-null   object
#  1   Cuisine types    1503 non-null   object
#  2   Rating           1503 non-null   object
#  3   Price            1503 non-null   object
#  4   Distance         1503 non-null   float64
#  5   Location         1503 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 70.6+ KB

# %%
df.describe()
# Out:
#           Distance
# count  1503.000000
# mean      5.031655
# std       2.776754
# min       0.030900
# 25%       3.100000
# 50%       4.500000
# 75%       6.200000
# max      25.800000

# %%
import random
qualities = [
    "Customizable Dishes", "Hospitality", "Weekend Brunch", "Good Music", "Young Crowd",
    "Ambience", "Peaceful Ambience", "Breakfast", "Courteous Staff", "Cafe",
    "Perfect Place", "Ambiance", "Brewed Beer", "Good Bartenders", "Extensive Mocktail Menu",
    "Variety of Beer", "Vintage Decor", "Live Sports Screening", "Sophisticated", 
    "Main Course", "Great Service", "Staff", "Delicious Food", "Quantity",
    "Great for Dates", "Exquisite Taste", "Fresh Ingredients", "Warm Atmosphere",
    "Attentive Service", "Friendly Staff", "Clean Environment", "Cozy Ambiance",
    "Creative Cuisine", "Memorable Experience", "Inviting Decor", "Seasonal Menu",
    "Sustainable Practices", "Local Sourcing", "Innovative Dishes", "Flavorful Creations",
    "Well-priced Options", "Impeccable Presentation", "Hospitable Staff", "Comfortable Seating",
    "Trendy Setting", "Diverse Menu", "Efficient Service", "Consistent Quality",
    "Authentic Flavors", "Satisfying Portions"
]

df['what_people_like_about_us'] = df.apply(lambda x: ', '.join(random.sample(qualities, 3)), axis=1)

# %%
df.head(20)
# Out:
#                               Restaurent name  \
# 0                Piazza Pizza By Little Italy
# 1                      Marleys  The Milkshake
# 2                            Molecule Air Bar
# 3                 The Salt Cafe Kitchen & Bar
# 4                                   Palm Burj
# 5                         Unplugged Courtyard
# 6                                     Hichkee
# 7                             The Numberdaars
# 8                             Barbeque Nation
# 9                                 The Nawaabs
# 10                Oasis - Radisson Hotel Agra
# 11                            Biryani By Kilo
# 12                              Masala Bistro
# 13                       Cafe G - Holiday Inn
# 14                              Downtown Cafe
# 15                             Pinch Of Spice
# 16  Cosmos Cafe & Bar - Fairfield By Marriott
# 17                        My Bar Headquarters
# 18                      Peshawri - ITC Mughal
# ...

# %%
df.dtypes
# Out:
# Restaurent name               object
# Cuisine types                 object
# Rating                        object
# Price                         object
# Distance                     float64
# Location                      object
# what_people_like_about_us     object
# dtype: object

# %%
df["what_people_like_about_us"]
# Out:
# 0           Staff, Flavorful Creations, Attentive Service
# 1       Good Music, Courteous Staff, Sustainable Pract...
# 2          Courteous Staff, Cozy Ambiance, Friendly Staff
# 3       Weekend Brunch, Sophisticated, Flavorful Creat...
# 4         Main Course, Customizable Dishes, Cozy Ambiance
#                               ...
# 1498        Warm Atmosphere, Variety of Beer, Young Crowd
# 1499    Inviting Decor, Sustainable Practices, Good Ba...
# 1500    Great Service, Main Course, Impeccable Present...
# 1501    Great Service, Well-priced Options, Attentive ...
# 1502    Clean Environment, Extensive Mocktail Menu, Ex...
# Name: what_people_like_about_us, Length: 1503, dtype: object

# %%
df.to_csv('All_city_data.csv', index=False)

# %%
df.head(20)
# Out:
#                               Restaurent name  \
# 0                Piazza Pizza By Little Italy
# 1                      Marleys  The Milkshake
# 2                            Molecule Air Bar
# 3                 The Salt Cafe Kitchen & Bar
# 4                                   Palm Burj
# 5                         Unplugged Courtyard
# 6                                     Hichkee
# 7                             The Numberdaars
# 8                             Barbeque Nation
# 9                                 The Nawaabs
# 10                Oasis - Radisson Hotel Agra
# 11                            Biryani By Kilo
# 12                              Masala Bistro
# 13                       Cafe G - Holiday Inn
# 14                              Downtown Cafe
# 15                             Pinch Of Spice
# 16  Cosmos Cafe & Bar - Fairfield By Marriott
# 17                        My Bar Headquarters
# 18                      Peshawri - ITC Mughal
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Restaurent name            1503 non-null   object
#  1   Cuisine types              1503 non-null   object
#  2   Rating                     1503 non-null   object
#  3   Price                      1503 non-null   object
#  4   Distance                   1503 non-null   float64
#  5   Location                   1503 non-null   object
#  6   what_people_like_about_us  1503 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 82.3+ KB

# %%
df['textual_features'] = df['Cuisine types']  + df['what_people_like_about_us'] + df['Price'] +df['Rating']

# %%
df.head(5)
# Out:
#                 Restaurent name  \
# 0  Piazza Pizza By Little Italy
# 1        Marleys  The Milkshake
# 2              Molecule Air Bar
# 3   The Salt Cafe Kitchen & Bar
# 4                     Palm Burj
#
#                                        Cuisine types Rating           Price  \
# 0                                              Pizza    3.9    ₹200 for two
# 1  Beverages, Desserts, Ice Cream, Shake, Burger,...    3.7    ₹400 for two
# 2        North Indian, Chinese, Continental, Italian    4.6  ₹2,000 for two
# 3  North Indian, Continental, Chinese, Italian, F...    4.9  ₹1,800 for two
# 4  North Indian, Chinese, Continental, Sushi, Sic...    4.5  ₹2,200 for two
#
#    Distance         Location  \
# 0       2.5    Tajganj, Agra
# 1       3.7    Tajganj, Agra
# 2       4.8    Tajganj, Agra
# 3       3.8    Tajganj, Agra
# 4       1.9  Rakabganj, Agra
#
#                            what_people_like_about_us  \
# 0      Staff, Flavorful Creations, Attentive Service
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['textual_features'])

# %%
tfidf_matrix
# Out:
# <1503x725 sparse matrix of type '<class 'numpy.float64'>'
# 	with 20187 stored elements in Compressed Sparse Row format>

# %%
print(tfidf_matrix[0][0])
# Out:
#   (0, 708)	0.16178146507279742
#   (0, 374)	0.08805037907210375
#   (0, 3)	0.28263626039310263
#   (0, 638)	0.23207534347260783
#   (0, 42)	0.3568861158550248
#   (0, 255)	0.3410395676724108
#   (0, 324)	0.3717081041360786
#   (0, 579)	0.6711848228904781

# %%
from sklearn.metrics.pairwise import cosine_similarity
def recommend_restaurants(user_food, user_location, top_n=5):
    
    user_input = tfidf_vectorizer.transform([user_food])

    
    filtered_restaurants = df[df['Location'] == user_location]

    
    similarities = cosine_similarity(user_input, tfidf_matrix[filtered_restaurants.index])

    
    top_indices = similarities.argsort()[0][-top_n:][::-1]
    recommendations = filtered_restaurants.iloc[top_indices]

    return recommendations[['Restaurent name', 'Cuisine types', 'Rating', 'Price', 'Distance', 'Location', 'what_people_like_about_us']]

# %%
df.columns
# Out:
# Index(['Restaurent name', 'Cuisine types', 'Rating', 'Price', 'Distance',
#        'Location', 'what_people_like_about_us', 'textual_features'],
#       dtype='object')

# %%
df.columns
recommendations = recommend_restaurants("Italian", "Tajganj, Agra")
recommendations
# Out:
#                      Restaurent name  \
# 34                   La Pino'z Pizza
# 473  The Chamber - Kitchen & Taproom
# 38           Tease Me - Rooftop Cafe
# 110          Golden China Restaurant
# 3        The Salt Cafe Kitchen & Bar
#
#                                          Cuisine types Rating           Price  \
# 34                    Pizza, Pasta, Italian, Fast Food    3.3    ₹500 for two
# 473  North Indian, Chinese, Italian, Fast Food, Bev...    4.0  ₹1,200 for two
# 38                    Italian, North Indian, Fast Food    4.3  ₹1,500 for two
# 110  Chinese, Rolls, North Indian, Mughlai, Biryani...    3.7  ₹1,000 for two
# 3    North Indian, Continental, Chinese, Italian, F...    4.9  ₹1,800 for two
#
#      Distance       Location  \
# 34        3.1  Tajganj, Agra
# 473       4.4  Tajganj, Agra
# 38        2.2  Tajganj, Agra
# 110       3.5  Tajganj, Agra
# 3         3.8  Tajganj, Agra
#
#                              what_people_like_about_us
# ...

# %%
import pickle

# %%
# Save the TF-IDF model and other necessary components
with open('tfidf_model.pkl', 'wb') as f:
    pickle.dump(tfidf_vectorizer, f)

# %%
df.to_csv('restaurants_data.csv', index=False)
